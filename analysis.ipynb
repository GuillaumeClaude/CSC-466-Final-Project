# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\guill\CSC-466-Final-Project\Test_Out.csv", sep=",")
delay = pd.read_csv(r"C:\Users\guill\CSC-466-Final-Project\delay.csv", sep=",")
delay = delay.drop(['Unnamed: 2'], axis = 1)
delay.head()
# Out:
#    detection_rate     t
# 0            0.32  10.0
# 1            0.70  20.0
# 2            0.84  30.0
# 3            0.84  40.0
# 4            0.78  50.0

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
time = delay['t']
time = time.tolist()
print(time)

detection_rate = delay['detection_rate']
detection_rate = detection_rate.tolist()
#time = [20, 50]
#detection_rate = [0.9,0.7]
ax.plot(time, detection_rate, marker='o', linestyle='--', label='Delay')
plt.legend()
plt.xlabel("Time")
plt.ylabel("Detection Rate")
plt.show()
# Out:
# [10.0, 20.0, 30.0, 40.0, 50.0, 60.0, 70.0, 80.0, 90.0, 100.0]
